# %% [markdown]
# # Interpolation of TOC data for comparison between multiple sites

# %% [markdown]
# ## Importing needed libraries

# %%
# %matplotlib inline
# %config IPCompleter.greedy=True
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy
from psycopg2.extras import NumericRange
password = open('../password.txt', 'r').read()

# %% [markdown]
# ## Get data from database

# %% [markdown]
# #### Connecting to the database

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:%s@localhost/MAYHEM-Example" % password)
con = engine.connect()

# %% [markdown]
# #### Insert age depth model output and organic data into dataframe

# %%
df_model_output = pd.read_sql('modeloutput', con)
df_model_output = df_model_output.sort_values(by = 'measurementid', ignore_index = True)
df_model_output = df_model_output[df_model_output['model_name'] == 'Undatable']
df_measurement = pd.read_sql('measurement', con)
df_organics = pd.read_sql('organic', con)

# %% [markdown]
# #### Close the connection to the database

# %%
con.close()

# %% [markdown]
# ## Prepare data for interpolation

# %% [markdown]
# #### Merge TOC data with age depth model median output

# %%
df_toc = df_organics[['measurementid','toc']].copy()

# %%
df_toc.dropna(inplace = True)

# %%
for index, row in df_toc.iterrows():
    if type(row['toc']) == NumericRange and row['toc'].upper == row['toc'].lower:
        df_toc.at[index, 'toc'] = row['toc'].upper
    else:
        df_toc.drop(index, inplace=True)

# %%
df_model = pd.merge(df_model_output[['measurementid', 'modeloutput_median']],
                   df_measurement,
                   how = 'outer',
                   on = ['measurementid'])
df_model.drop_duplicates(['coreid','compositedepth'], inplace = True)

# %%
df_toc_raw = pd.merge(df_toc,
                 df_measurement,
                 how = 'left',
                 on = ['measurementid'])

# %%
df_toc_raw = pd.merge(df_toc_raw,
                 df_model,
                 how = 'outer',
                 on = ['coreid', 'compositedepth'])

# %%
df_toc_raw['toc'] = df_toc_raw['toc'].astype(np.float32)

# %%
#for index, row in df_toc_raw.iterrows():
#    if pd.isna(row['measurementid_x']) == True:
#        df_toc_raw.drop(index, inplace = True)
#    else: 
#        pass

# %% [markdown]
# #### Sort dataframe and remove unnecessary columns and set index to CoreID

# %%
df_toc_multiple = df_toc_raw.sort_values(by = ['coreid', 'compositedepth'], ignore_index = True)\
.drop(columns = ['measurementid_y','measurementid_x'])
df_toc_multiple['compositedepth'] = df_toc_multiple['compositedepth'].astype(np.float32)

# %%
#### Changing the look of the graphic
SMALL_SIZE = 8
MEDIUM_SIZE = 15
BIGGER_SIZE = 18
plt.rcdefaults()
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
######

plt.subplots(figsize=(15,8))
sns.scatterplot(x = 'compositedepth', y = 'toc', hue = 'coreid', data = df_toc_multiple, legend = 'brief')
plt.legend(loc = 'upper right')
plt.xlim(0, 2500)
plt.ylabel('TOC [%]', weight = 'bold')
plt.xlabel('Composite Depth [cm]', weight = 'bold')
plt.grid(True)
#plt.savefig('Figures/TOC_values_All_Cores_depth.pdf', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
depth_res = df_toc_multiple.copy()

# %%
depth_res.drop(columns = ['modeloutput_median'], inplace = True)

# %%
depth_res.dropna(inplace = True)

# %%
core_res = pd.DataFrame()
for i in depth_res.coreid.unique():
    diff_check = depth_res[depth_res['coreid'] == i].compositedepth.diff().dropna()
    core_array = [[i, diff_check.mean(), diff_check.min(), diff_check.max()]]
    core_res = core_res.append(core_array)
core_res.rename(columns = {0 : 'CoreID', 1: 'Mean_Depth_Res', 2: 'Min_Depth_Res', 3: 'Max_Depth_Res'}, inplace = True)

# %%
core_res.describe()
# Out:
#        Mean_Depth_Res  Min_Depth_Res  Max_Depth_Res
# count       23.000000      23.000000      23.000000
# mean         6.011144       2.945652      13.315217
# std          5.241761       3.093208      12.348679
# min          0.617366       0.500000       1.000000
# 25%          1.949495       1.000000       2.125000
# 50%          4.746835       2.000000      10.000000
# 75%          9.646904       2.500000      20.000000
# max         20.181818      10.000000      40.000000

# %%
#### Changing the look of the graphic
SMALL_SIZE = 8
MEDIUM_SIZE = 15
BIGGER_SIZE = 18
plt.rcdefaults()
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
######

plt.subplots(figsize=(15,8))
sns.scatterplot(x = 'modeloutput_median', y = 'toc', hue = 'coreid', data = df_toc_multiple, legend = 'brief')
plt.legend(loc = 'upper right')
plt.xlim(-100, 60000)
plt.ylabel('TOC [%]', weight = 'bold')
plt.xlabel('Calibrated Age [cal yr BP]', weight = 'bold')
plt.grid(True)
#plt.savefig('Figures/TOC_values_All_Cores_age.pdf', dpi = 300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### Get a list of unique CoreIDs

# %%
df_toc_multiple = df_toc_multiple.set_index('coreid')
List_Unique_CoreID = list(df_toc_multiple.index.unique())

# %% [markdown]
# **Individually interpolate (piecewise polynomial) the model output median for the composite depth measurement of TOC for each CoreID, so that every TOC value has a median age\
# Then combine each CoreID in one dataframe with the age median as index**

# %%
df1 = pd.DataFrame(columns = ['toc'])
for i in List_Unique_CoreID:
    df2 = df_toc_multiple.loc[i]
    df2 = df2.set_index('compositedepth')
    df2 = df2.dropna(how = 'all')
    df2['modeloutput_median'] = df2.modeloutput_median.interpolate('from_derivatives') ## scipy.interpolate.BPoly.from_derivatives
    ### loop to remove NA's
    for j in range(0, len(df2.modeloutput_median)):
        try:
            if np.isnan(df2.iloc[j,1]):
                df2 = df2.drop(df2.index[[j]])
            else:
                pass
        except (IndexError):
            if np.isnan(df2.iloc[-1,1]):
                df2 = df2.drop(df2.index[-1])
            else:
                pass
    ####        
    ### loop to remove big jumps in age-depth model
    for k in range(0,len(df2.index)):
        try:
            if (df2.iloc[k+1,1]- df2.iloc[k,1])/(df2.index[k+1]-df2.index[k]) >= 5000:
                df2 = df2.drop(df2.index[(k+1):-1])
            else:
                pass
        except (IndexError):
            if (df2.iloc[-1,1]- df2.iloc[-2,1])/(df2.index[-1]-df2.index[-2]) >= 5000:
                df2 = df2.drop(df2.index[[-1]])
            else:
                pass
    ####
    df2 = df2.astype({'modeloutput_median': 'int32'})
    df2 = df2.set_index('modeloutput_median')
    df1 = pd.merge(df1, df2, how = 'outer', left_index = True, right_index = True)
### Remove all empty rows and columns
df1 = df1.dropna(how = 'all', axis = 1)
df1 = df1.dropna(how = 'all', axis = 0)
#####
### Rename columns to CoreID
df1.columns = List_Unique_CoreID

# %% [markdown]
# #### Remove duplicates in the dataframe

# %%
df_combined = df1[~df1.index.duplicated()]

# %% [markdown]
# #### Enlarge age median range to a one year resolution

# %%
df_combined = df_combined.reindex(range(int(df_combined.index[0]),int(df_combined.index[-1])+1, 1))

# %% [markdown]
# #### Piecewise interpolate polynomial the TOC value for now evenly spaced out ages

# %%
df_combined_interpolate = df_combined.interpolate('from_derivatives')
df_combined_interpolate = df_combined_interpolate.reset_index()

# %% [markdown]
# #### Stack CoreIDs for plotting with age median and TOC value

# %%
df_interpolate_TOC = pd.DataFrame()
for i in range(1, len(df_combined_interpolate.columns)):
    df_i_TOC = df_combined_interpolate.iloc[:,[0,i]].dropna(how = 'any') 
    individual_coreid = []
    for k in range(0, len(df_i_TOC)):
        individual_coreid.append(df_i_TOC.columns[1])
    df_i_TOC = df_i_TOC.set_index([individual_coreid])
    df_i_TOC = df_i_TOC.rename(columns = {df_i_TOC.columns[1] : 'toc'})
    df_interpolate_TOC = df_interpolate_TOC.append(df_i_TOC)
df_interpolate_TOC = df_interpolate_TOC.reset_index().rename(columns = {'index' : 'coreid'})

# %% [markdown]
# ## Plotting the data

# %%
#### Changing the look of the graphic
SMALL_SIZE = 8
MEDIUM_SIZE = 15
BIGGER_SIZE = 18
plt.rcdefaults()
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
######

fig, ax = plt.subplots(figsize=(15,8))
ax = sns.lineplot(x = 'modeloutput_median', y = 'toc', hue = 'coreid', data = df_interpolate_TOC, legend = 'brief')
plt.legend(loc = 'upper right')
plt.xlim(-100, 60000)
plt.ylabel('TOC [%]', weight = 'bold')
plt.xlabel('Calibrated Age [cal yr BP]', weight = 'bold')
plt.grid(True)
#plt.savefig('Figures/TOC_values_interpolated_All_Cores.pdf', dpi = 300, bbox_inches = 'tight')
plt.show()
